# %%
from marginal_finder import ComtradeMarketFinder

# %%
belgium = ComtradeMarketFinder(market='Belgium')

# %%
belgium.multi_year_markets(tMarket=0.001, tYear=0.5)
# Out:
# Finding markets for Belgium, for 2003 to 2013 (inclusive). tMarket = 0.1%, tYear = 50.0%
#
# ...
# 2003
# ----------------------------------------------------------------------------------------------------
# Iteration 1... Checking Belgium
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Iteration 2... Checking Germany, Spain, France, Indonesia, Luxembourg, Netherlands, Turkey
# Reference market production = 170892000000.0
# ----------------------------------------------------------------------------------------------------
# Adding Czechia to market (via Germany)
# Adding Italy, Portugal, Russian Federation to market (via Spain)
# No new markets from France
# No new markets from Indonesia
# No new markets from Luxembourg
# No new markets from Netherlands
# No new markets from Turkey
# ...

# %%
belgium.tMarket_tYear_suppliers
# Out:
# ['Belgium',
#  'Germany',
#  'Spain',
#  'France',
#  'Luxembourg',
#  'Netherlands',
#  'Turkey',
#  'Czechia',
#  'Italy',
#  'Portugal',
#  'Slovakia',
#  'Greece',
#  'Croatia',
#  'Denmark',
#  'Malaysia']

# %%
greece = ComtradeMarketFinder(market='Greece', tMarket=0.001, tYear=0.5)

# %%
greece.multi_year_markets([x for x in range(2003,2014)])
# Out:
# Finding markets for Greece, for 2003 to 2013 (inclusive). tMarket = 0.1%, tYear = 50.0%
#
# ...
# 2003
# ----------------------------------------------------------------------------------------------------
# Iteration 1... Checking Greece
# ----------------------------------------------------------------------------------------------------
# ...
# 2004
# ----------------------------------------------------------------------------------------------------
# Iteration 1... Checking Greece
# ----------------------------------------------------------------------------------------------------
# ...
# 2005
# ----------------------------------------------------------------------------------------------------
# Iteration 1... Checking Greece
# ----------------------------------------------------------------------------------------------------
# ...
# 2006
# ----------------------------------------------------------------------------------------------------
# Iteration 1... Checking Greece
# ...

# %%
greece.tMarket_tYear_suppliers
# Out:
# ['Greece', 'Turkey']
